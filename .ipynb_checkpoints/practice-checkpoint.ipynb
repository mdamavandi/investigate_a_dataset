# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from copy import deepcopy
# %matplotlib inline

# %%
compensation = pd.read_csv('hourly_compensation.csv')
compensation.head()
# Out:
#      country   1980   1981   1982   1983   1984   1985   1986   1987   1988  \
# 0  Australia   8.44   9.76   9.94   9.27   9.80   8.18   8.55   9.52  11.44
# 1    Austria   8.87   7.77   7.76   7.79   7.35   7.57  10.72  13.65  14.49
# 2    Belgium  11.74  10.28   8.93   8.53   7.98   8.21  11.25  13.96  14.72
# 3     Brazil    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4     Canada   8.87   9.79  10.70  11.41  11.41  11.20  11.33  12.30  13.77
#
#    ...       1997       1998       1999       2000   2001       2002  \
# 0  ...  16.709999  15.110000  15.940000  14.410000  13.33  15.400000
# 1  ...  21.850000  22.020000  21.629999  19.120001  19.07  20.660000
# 2  ...  22.280001  22.620001  22.139999  20.129999  19.84  21.770000
# 3  ...   5.770000   5.490000   3.390000   3.500000   2.97   2.570000
# 4  ...  16.830000  15.930000  16.100000  16.480000  16.27  16.799999
#
#         2003       2004       2005       2006
# 0  19.790001  23.379999  25.110001  26.139999
# 1  25.420000  28.389999  29.360001  30.459999
# 2  26.549999  30.010000  30.790001  31.850000
# 3   2.740000   3.140000   4.160000   4.910000
# 4  19.600000  21.850000  23.980000  25.740000
#
# [5 rows x 28 columns]

# %%
weekly_hours = pd.read_csv('hours_worked_per_week.csv')
weekly_hours.head()
# Out:
#       country       1980       1981       1982       1983       1984  \
# 0   Argentina        NaN        NaN        NaN        NaN        NaN
# 1   Australia  34.578846  34.578846  34.376923  34.117307  34.415384
# 2     Austria        NaN        NaN        NaN        NaN        NaN
# 3  Bangladesh        NaN        NaN        NaN        NaN        NaN
# 4     Belgium        NaN        NaN        NaN  34.000000  34.480769
#
#         1985       1986       1987       1988  ...       1999       2000  \
# 0        NaN        NaN        NaN        NaN  ...  35.000000        NaN
# 1  34.338461  34.482692  34.655769  34.819230  ...  34.363462  34.332693
# 2        NaN        NaN        NaN        NaN  ...  31.492307  31.378845
# 3        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 4  34.596154  34.211538  33.903846  33.653846  ...  30.403846  29.884615
#
#         2001       2002       2003       2004       2005       2006  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1  33.742307  33.467309  33.411539  33.596154  33.298077  33.140386
# 2  31.351924  31.384615  31.567308  31.736539  31.844231  31.817308
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4  30.326923  30.365385  30.288462  29.788462  30.096154  30.211538
#
#         2007  Unnamed: 29
# 0        NaN          NaN
# 1  33.109614          NaN
# 2  31.761346          NaN
# 3        NaN          NaN
# 4  30.115385          NaN
#
# [5 rows x 30 columns]

# %%
trade_balance = pd.read_csv('trade_balance.csv')
trade_balance.head()
# Out:
#           country          1960          1961         1962          1963  \
# 0     Afghanistan -1.555555e+07 -1.999999e+07 -24444430.22 -5.777779e+07
# 1         Albania           NaN           NaN          NaN           NaN
# 2         Algeria -7.653547e+08 -5.176123e+08 -20510459.26 -3.281672e+08
# 3  American Samoa           NaN           NaN          NaN           NaN
# 4         Andorra           NaN           NaN          NaN           NaN
#
#            1964         1965         1966          1967         1968  ...  \
# 0 -7.333330e+07 -102222210.8 -139999994.3 -1.244444e+08 -86666672.36  ...
# 1           NaN          NaN          NaN           NaN          NaN  ...
# 2 -1.267222e+08 -101274850.3   40509940.1  6.076491e+07 -40509940.10  ...
# 3           NaN          NaN          NaN           NaN          NaN  ...
# 4           NaN          NaN          NaN           NaN          NaN  ...
#
#            2002          2003          2004          2005          2006  \
# 0 -1.346906e+09 -2.330684e+09 -2.698376e+09 -3.139072e+09 -3.360200e+09
# 1 -1.170065e+09 -1.427486e+09 -1.624591e+09 -2.014800e+09 -2.197351e+09
# 2  5.520554e+09  9.789367e+09  1.225881e+10  2.392325e+10  3.174253e+10
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#            2007          2008          2009          2010  2011
# 0 -3.977873e+09 -3.831084e+09 -6.096070e+09 -6.565330e+09   NaN
# 1 -2.803289e+09 -3.450694e+09 -3.088848e+09 -2.590635e+09   NaN
# 2  3.166455e+10  3.995169e+10  6.171963e+09  1.511871e+10   NaN
# 3           NaN           NaN           NaN           NaN   NaN
# 4           NaN           NaN           NaN           NaN   NaN
#
# [5 rows x 53 columns]

# %%
compensation = compensation.melt(id_vars=['country'], var_name='year', value_name='hourly_rate')
# compensation.dropna(subset=['hourly_rate']).head()

# %%
weekly_hours = weekly_hours.melt(id_vars=['country'], var_name='year', value_name='working_hours')
# weekly_hours
# weekly_hours.dropna(subset=['working_hours']).head()

# %%
trade_balance = trade_balance.melt(id_vars=['country'], var_name='year', value_name='trade_balance')

# %%
compensation = compensation.dropna(subset=['hourly_rate'])
weekly_hours = weekly_hours.dropna(subset=['working_hours'])
trade_balance = trade_balance.dropna(subset=['trade_balance'])

# %%
combined = compensation.merge(weekly_hours, on=['country','year'], how='inner').merge(trade_balance, on=['country','year'], how='inner')

# %%
combined[combined['country'] == 'United States']
# Out:
#            country  year  hourly_rate  working_hours  trade_balance
# 13   United States  1980     9.630000      34.807692  -1.300000e+10
# 27   United States  1981    10.620000      34.634615  -1.260000e+10
# 41   United States  1982    11.430000      34.557692  -2.000000e+10
# 59   United States  1983    11.840000      34.923077  -5.160000e+10
# 77   United States  1984    12.270000      35.269231  -1.027000e+11
# 95   United States  1985    12.710000      35.230769  -1.152000e+11
# 115  United States  1986    12.990000      35.096154  -1.326000e+11
# 136  United States  1987    13.300000      35.192308  -1.449000e+11
# 157  United States  1988    13.610000      35.250000  -1.101000e+11
# 178  United States  1989    14.040000      35.480769  -8.790000e+10
# 200  United States  1990    14.810000      35.134615  -7.760000e+10
# 222  United States  1991    15.520000      34.903846  -2.690000e+10
# 244  United States  1992    15.950000      34.923077  -3.280000e+10
# 267  United States  1993    16.370001      35.096154  -6.440000e+10
# 291  United States  1994    16.780001      35.250000  -9.270000e+10
# 317  United States  1995    17.170000      35.384615  -9.070000e+10
# 343  United States  1996    17.740000      35.230769  -9.630000e+10
# 370  United States  1997    18.200001      35.423077  -1.014000e+11
# 396  United States  1998    18.520000      35.442308  -1.618000e+11
# 423  United States  1999    18.900000      35.461538  -2.621000e+11
# 450  United States  2000    19.650000      35.230769  -3.821000e+11
# 477  United States  2001    20.520000      34.826923  -3.710000e+11
# 504  United States  2002    21.600000      34.750000  -4.272000e+11
# 531  United States  2003    22.480000      34.557692  -5.041000e+11
# 558  United States  2004    23.129999      34.596154  -6.187000e+11
# 585  United States  2005    23.809999      34.519231  -7.227000e+11
# 611  United States  2006    23.820000      34.557692  -7.693000e+11

# %%
sns.pairplot(combined[combined['country'] == 'United States'], vars=['hourly_rate', 'working_hours', 'trade_balance'], hue='year')
# Out:
# C:\Users\mackenzie.damavandi\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\mackenzie.damavandi\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\mackenzie.damavandi\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:20: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)
# C:\Users\mackenzie.damavandi\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %%
countries = pd.concat([
    combined[combined['year'] == '1980'],
    combined[combined['year'] == '1985'],
    combined[combined['year'] == '1990'],
    combined[combined['year'] == '1995'],
    combined[combined['year'] == '2000'],
    combined[combined['year'] == '2005']
]).groupby(['country']).size()
test = combined[combined['year'].isin(['1980','1985','1990','1995','2000','2005'])]
final = test[test['country'].isin(list(countries.where(countries > 5).dropna().index))]
# list(countries)
#     .concat()
#     any([
#         ,
#         ,
#         combined['year'] == '1990',
#         combined['year'] == '1995',
#         combined['year'] == '2000',
#         combined['year'] == '2005'
#     ])
# ]

# %%
sns.pairplot(final, vars=['hourly_rate','working_hours'], hue='country')

# %%
plt.figure(num=None, figsize=(11,9), dpi=80)
ax = sns.boxplot(x='year', y='working_hours', data=final, whis=np.inf)
ax = sns.swarmplot(x='year', y='working_hours', hue='country', data=final)
l = ax.legend()
ax.legend(loc='best', frameon=False)

# %%
plt.figure(num=None, figsize=(11,9), dpi=80)
ax = sns.boxplot(x='year', y='trade_balance', data=final, whis=np.inf)
ax = sns.swarmplot(x='year', y='trade_balance', hue='country', data=final)
l = ax.legend()
ax.legend(loc='best', frameon=False)

# plt.figure(num=None, figsize=(11,9), dpi=80)
# ax = sns.lineplot(x='year', y='trade_balance', data=final[final['country'].isin(['Spain'])])

# %%
plt.figure(num=None, figsize=(11,9), dpi=80)
ax = sns.boxplot(x='year', y='hourly_rate', data=final, whis=np.inf)
ax = sns.swarmplot(x='year', y='hourly_rate', hue='country', data=final)
l = ax.legend()
ax.legend(loc='best', frameon=False)

# %%
final.head()
# Out:
#      country  year  hourly_rate  working_hours  trade_balance
# 0  Australia  1980         8.44      34.578846   7.231198e+08
# 1     Canada  1980         8.87      34.849999   4.982894e+09
# 2    Denmark  1980        10.83      31.898076  -1.127593e+09
# 3    Finland  1980         8.61      35.563462  -6.981192e+08
# 4     France  1980         8.90      35.423077  -1.088140e+10

# %%
trade = deepcopy(final.pivot(index='country', columns='year', values='trade_balance'))

# %%
(trade.iloc[:,1] - trade.iloc[:,0]) / trade.iloc[:,0] * 100
# Out:
# country
# Australia        -622.630387
# Canada             66.104701
# Denmark           -86.893669
# Finland          -153.592079
# France            -77.666403
# Italy             -85.759161
# Japan            -572.873202
# Korea, Rep.      -111.329404
# Norway             21.655859
# Spain            -167.066453
# Sweden           -235.735505
# Switzerland      -209.780932
# United Kingdom    -51.123095
# United States     786.153846
# dtype: float64

# %%
i = 1
trade_delta = {}
year_list = ['1985','1990','1995','2000','2005']
while i < len(trade.iloc[0]):
    trade_delta[year_list[i-1]] = (trade.iloc[:,i] - trade.iloc[:,i-1]) / 5
    #(trade.iloc[:,i] - trade.iloc[:,i-1]) / abs(trade.iloc[:,i-1]) * 100
    i += 1

# %%
#del(trade_delta)

# %%
# print(trade[trade.index == 'Spain']['1990'])
# print(trade[trade.index == 'Spain']['1995'])
# print((trade[trade.index == 'Spain']['1995'] - trade[trade.index == 'Spain']['1990']))
# (trade[trade.index == 'Spain']['1995'] - trade[trade.index == 'Spain']['1990']) / abs(trade[trade.index == 'Spain']['1990']) * 100
# trade_delta
pd.DataFrame(trade_delta).mean(axis=1)
# Out:
# country
# Australia        -7.293007e+08
# Canada            1.489633e+09
# Denmark           5.507174e+08
# Finland           3.484242e+08
# France           -1.059069e+08
# Italy             4.502798e+08
# Japan             2.915929e+09
# Korea, Rep.       1.114875e+09
# Norway            1.820522e+09
# Spain            -2.189712e+09
# Sweden            1.225736e+09
# Switzerland       1.079782e+09
# United Kingdom   -3.639617e+09
# United States    -2.838800e+10
# dtype: float64

# %%
wage = deepcopy(final.pivot(index='country', columns='year', values='hourly_rate'))
work = deepcopy(final.pivot(index='country', columns='year', values='working_hours'))

i = 1
wage_delta = {}
work_delta = {}
while i < len(trade.iloc[0]):
    wage_delta[year_list[i-1]] = (wage.iloc[:,i] - wage.iloc[:,i-1]) / abs(wage.iloc[:,i-1]) * 100
    work_delta[year_list[i-1]] = (work.iloc[:,i] - work.iloc[:,i-1]) / abs(work.iloc[:,i-1]) * 100
    i += 1

# %%
print(pd.DataFrame(wage_delta).mean(axis=1))
print(pd.DataFrame(work_delta).mean(axis=1))
# Out:
# country
# Australia         28.470893
# Canada            23.700283
# Denmark           37.024051
# Finland           38.789587
# France            30.100378
# Italy             35.158863
# Japan             38.742090
# Korea, Rep.       79.001522
# Norway            35.032452
# Spain             37.429366
# Sweden            28.198431
# Switzerland       32.259183
# United Kingdom    33.725611
# United States     20.011053
# dtype: float64
# country
# Australia        -0.743725
# Canada           -0.824845
# Denmark          -1.140244
# Finland          -1.460847
# France           -3.381804
# Italy            -0.430253
# Japan            -3.478073
# Korea, Rep.      -3.879097
# Norway           -2.107330
# Spain            -2.615341
# Sweden            1.176885
# Switzerland      -1.536082
# United Kingdom   -1.111593
# United States    -0.160068
# dtype: float64
